# %%
from music21 import converter, instrument, note, chord, stream, corpus, environment, graph
import music21
import glob

print("Starting to read files...")
streams = []
notes = []
for file in glob.glob("midi_classic/*.mid"):
    print(file)
    midi = converter.parse(file)
    streams.append(midi)
    print("file parsed")
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts: # file has instrument parts
        notes_to_parse = parts.parts[0].recurse()
    else: # file has notes in a flat structure
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))
print("Files read")
# Out:
# Starting to read files...
# midi_classic\appass_1.mid
# file parsed
# midi_classic\appass_2.mid
# file parsed
# midi_classic\appass_3.mid
# file parsed
# midi_classic\beethoven_hammerklavier_1.mid
# file parsed
# midi_classic\beethoven_hammerklavier_2.mid
# file parsed
# midi_classic\beethoven_hammerklavier_3.mid
# file parsed
# midi_classic\beethoven_hammerklavier_4.mid
# file parsed
# midi_classic\beethoven_les_adieux_1.mid
# file parsed
# midi_classic\beethoven_les_adieux_2.mid
# file parsed
# midi_classic\beethoven_les_adieux_3.mid
# file parsed
# midi_classic\beethoven_opus10_1.mid
# file parsed
# midi_classic\beethoven_opus10_2.mid
# file parsed
# midi_classic\beethoven_opus10_3.mid
# file parsed
# midi_classic\beethoven_opus22_1.mid
# file parsed
# midi_classic\beethoven_opus22_2.mid
# file parsed
# midi_classic\beethoven_opus22_3.mid
# file parsed
# midi_classic\beethoven_opus22_4.mid
# file parsed
# midi_classic\beethoven_opus90_1.mid
# file parsed
# midi_classic\beethoven_opus90_2.mid
# file parsed
# midi_classic\elise.mid
# file parsed
# midi_classic\mond_1.mid
# file parsed
# midi_classic\mond_2.mid
# file parsed
# midi_classic\mond_3.mid
# file parsed
# midi_classic\mz_311_1.mid
# file parsed
# midi_classic\mz_311_2.mid
# file parsed
# midi_classic\mz_311_3.mid
# file parsed
# midi_classic\mz_330_1.mid
# file parsed
# midi_classic\mz_330_2.mid
# file parsed
# midi_classic\mz_330_3.mid
# file parsed
# midi_classic\mz_331_1.mid
# file parsed
# midi_classic\mz_331_2.mid
# file parsed
# midi_classic\mz_331_3.mid
# file parsed
# midi_classic\mz_332_1.mid
# file parsed
# midi_classic\mz_332_2.mid
# file parsed
# midi_classic\mz_332_3.mid
# file parsed
# midi_classic\mz_333_1.mid
# file parsed
# midi_classic\mz_333_2.mid
# file parsed
# midi_classic\mz_333_3.mid
# file parsed
# midi_classic\mz_545_1.mid
# file parsed
# midi_classic\mz_545_2.mid
# file parsed
# midi_classic\mz_545_3.mid
# file parsed
# midi_classic\mz_570_1.mid
# file parsed
# midi_classic\mz_570_2.mid
# file parsed
# midi_classic\mz_570_3.mid
# file parsed
# midi_classic\pathetique_1.mid
# file parsed
# midi_classic\pathetique_2.mid
# file parsed
# midi_classic\pathetique_3.mid
# file parsed
# midi_classic\waldstein_1.mid
# file parsed
# midi_classic\waldstein_2.mid
# file parsed
# midi_classic\waldstein_3.mid
# file parsed
# Files read

# %%
def from_graph_to_pianoroll(graph, window_size):
    data_matrix = []
    for item in graph.data:
        if item[0] != '':
            for subitem in item[1]:
                data_matrix.append((item[0], subitem[0], subitem[1]))
    data_matrix = np.array(data_matrix)
    values = []
    for i in range(len(data_matrix)):
        values.append(data_matrix[i][1])
    values = np.array(values)
    values = values.astype(np.float)
    last_bar = max(values)

    sr = 1.0/window_size
    last_bar = last_bar.astype(np.float)
    piano_roll = np.zeros((128, int(np.ceil(last_bar * sr)))) 
    for event in data_matrix:
        pitch = event[0]
        pitch = pitch.replace("\\", "")
        pitch = pitch.replace("$", "")
        pitch = pitch.replace('♯','#')
        pitch = pitch.replace('♭','b')
        event1 = event[1].astype(np.float)
        event2 = event[2].astype(np.float)
        start_idx = int(event1 * sr)
        end_idx = start_idx + int(event2 * sr) + 1
        piano_roll[music21.pitch.Pitch(pitch).midi, start_idx:end_idx] = 1

    return piano_roll

def pianoRollToVertical(pianoRoll):
    w = len(pianoRoll)
    h = len(pianoRoll[0])
    aux = [[0 for x in range(w)] for y in range(h)]
    for x in range(len(pianoRoll)):
        for y in range(len(pianoRoll[x])):
            aux[y][x] = pianoRoll[x][y]

    return aux

def streamToPianoRoll(stream):
    g = graph.plot.HorizontalBarPitchSpaceOffset(stream)
    g.extractData()
    pianoRoll = from_graph_to_pianoroll(g, 1)
    return pianoRoll

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline

n_vocab = len(set(notes))
sequence_length = 10
# get all pitch names
pitchnames = sorted(set(item for item in notes))
# create a dictionary to map pitches to integers
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
network_input = []
network_output = []
# create input sequences and the corresponding outputs
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(sequence_out)
    
n_patterns = len(network_input)
# reshape the input into a format compatible with LSTM layers
network_input = np.reshape(network_input, (n_patterns, sequence_length))
# normalize input
network_input = network_input / float(n_vocab)

# %%
X_train = network_input[0: int(len(network_input) * 0.8)]
X_test = network_input[int(len(network_input) * 0.8): len(network_input)]
Y_train = network_output[0: int(len(network_output) * 0.8)]
Y_test = network_output[int(len(network_output) * 0.8): len(network_output)]

# %%
# Models we will use
logistic = linear_model.LogisticRegression(solver='newton-cg', tol=1)
rbm = BernoulliRBM(random_state=0, verbose=True)

rbm_features_classifier = Pipeline(
    steps=[('rbm', rbm), ('logistic', logistic)])

# #############################################################################
# Training


rbm.learning_rate = 0.05
rbm.n_iter = 100
# More components tend to give better prediction performance, but larger
# fitting time
rbm.n_components = 1024

# for small values it will underfit the model, for large values it wil overfit the model
# (problem: how big is too big?)
# (solution: generaly you use C as a value close to the magnetute of the training data,
#  in this case I want to overfit so the patterns are learnt since the prediction output
#  will have less diversity than the real output)
logistic.C = 16000000

# Training RBM-Logistic Pipeline
rbm_features_classifier.fit(X_train, Y_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -19.41, time = 9.02s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -8.89, time = 19.42s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.71, time = 19.37s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.24, time = 19.30s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.20, time = 19.15s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.92, time = 18.96s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.40, time = 19.08s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.54, time = 18.97s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.42, time = 18.91s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.32, time = 18.97s
# [BernoulliRBM] Iteration 11, pseudo-likelihood = -3.20, time = 18.74s
# [BernoulliRBM] Iteration 12, pseudo-likelihood = -3.15, time = 18.67s
# [BernoulliRBM] Iteration 13, pseudo-likelihood = -2.86, time = 18.62s
# [BernoulliRBM] Iteration 14, pseudo-likelihood = -3.00, time = 18.74s
# [BernoulliRBM] Iteration 15, pseudo-likelihood = -2.94, time = 18.68s
# [BernoulliRBM] Iteration 16, pseudo-likelihood = -2.82, time = 18.68s
# [BernoulliRBM] Iteration 17, pseudo-likelihood = -2.72, time = 18.51s
# [BernoulliRBM] Iteration 18, pseudo-likelihood = -2.81, time = 18.48s
# [BernoulliRBM] Iteration 19, pseudo-likelihood = -2.76, time = 18.50s
# [BernoulliRBM] Iteration 20, pseudo-likelihood = -2.67, time = 18.59s
# [BernoulliRBM] Iteration 21, pseudo-likelihood = -2.69, time = 18.53s
# [BernoulliRBM] Iteration 22, pseudo-likelihood = -2.64, time = 18.55s
# [BernoulliRBM] Iteration 23, pseudo-likelihood = -2.73, time = 18.40s
# [BernoulliRBM] Iteration 24, pseudo-likelihood = -2.65, time = 18.48s
# [BernoulliRBM] Iteration 25, pseudo-likelihood = -2.68, time = 18.36s
# [BernoulliRBM] Iteration 26, pseudo-likelihood = -2.63, time = 18.99s
# [BernoulliRBM] Iteration 27, pseudo-likelihood = -2.68, time = 18.46s
# [BernoulliRBM] Iteration 28, pseudo-likelihood = -2.63, time = 18.52s
# [BernoulliRBM] Iteration 29, pseudo-likelihood = -2.59, time = 18.34s
# [BernoulliRBM] Iteration 30, pseudo-likelihood = -2.63, time = 18.56s
# [BernoulliRBM] Iteration 31, pseudo-likelihood = -2.69, time = 18.34s
# [BernoulliRBM] Iteration 32, pseudo-likelihood = -2.51, time = 18.36s
# [BernoulliRBM] Iteration 33, pseudo-likelihood = -2.58, time = 18.41s
# [BernoulliRBM] Iteration 34, pseudo-likelihood = -2.49, time = 18.44s
# [BernoulliRBM] Iteration 35, pseudo-likelihood = -2.62, time = 18.38s
# [BernoulliRBM] Iteration 36, pseudo-likelihood = -2.50, time = 18.42s
# [BernoulliRBM] Iteration 37, pseudo-likelihood = -2.65, time = 18.42s
# [BernoulliRBM] Iteration 38, pseudo-likelihood = -2.45, time = 18.28s
# [BernoulliRBM] Iteration 39, pseudo-likelihood = -2.52, time = 18.46s
# [BernoulliRBM] Iteration 40, pseudo-likelihood = -2.53, time = 18.42s
# [BernoulliRBM] Iteration 41, pseudo-likelihood = -2.55, time = 18.38s
# [BernoulliRBM] Iteration 42, pseudo-likelihood = -2.51, time = 18.41s
# [BernoulliRBM] Iteration 43, pseudo-likelihood = -2.47, time = 18.29s
# [BernoulliRBM] Iteration 44, pseudo-likelihood = -2.54, time = 18.27s
# [BernoulliRBM] Iteration 45, pseudo-likelihood = -2.57, time = 18.23s
# [BernoulliRBM] Iteration 46, pseudo-likelihood = -2.50, time = 18.37s
# [BernoulliRBM] Iteration 47, pseudo-likelihood = -2.48, time = 18.43s
# [BernoulliRBM] Iteration 48, pseudo-likelihood = -2.51, time = 18.35s
# [BernoulliRBM] Iteration 49, pseudo-likelihood = -2.49, time = 18.25s
# [BernoulliRBM] Iteration 50, pseudo-likelihood = -2.59, time = 18.20s
# [BernoulliRBM] Iteration 51, pseudo-likelihood = -2.54, time = 18.18s
# [BernoulliRBM] Iteration 52, pseudo-likelihood = -2.53, time = 18.19s
# [BernoulliRBM] Iteration 53, pseudo-likelihood = -2.51, time = 18.35s
# [BernoulliRBM] Iteration 54, pseudo-likelihood = -2.45, time = 18.25s
# [BernoulliRBM] Iteration 55, pseudo-likelihood = -2.50, time = 18.28s
# [BernoulliRBM] Iteration 56, pseudo-likelihood = -2.44, time = 18.34s
# [BernoulliRBM] Iteration 57, pseudo-likelihood = -2.50, time = 18.16s
# [BernoulliRBM] Iteration 58, pseudo-likelihood = -2.46, time = 18.15s
# [BernoulliRBM] Iteration 59, pseudo-likelihood = -2.43, time = 18.20s
# [BernoulliRBM] Iteration 60, pseudo-likelihood = -2.47, time = 18.31s
# [BernoulliRBM] Iteration 61, pseudo-likelihood = -2.46, time = 18.28s
# [BernoulliRBM] Iteration 62, pseudo-likelihood = -2.48, time = 18.25s
# [BernoulliRBM] Iteration 63, pseudo-likelihood = -2.42, time = 18.15s
# [BernoulliRBM] Iteration 64, pseudo-likelihood = -2.42, time = 18.01s
# [BernoulliRBM] Iteration 65, pseudo-likelihood = -2.44, time = 18.02s
# [BernoulliRBM] Iteration 66, pseudo-likelihood = -2.49, time = 18.09s
# [BernoulliRBM] Iteration 67, pseudo-likelihood = -2.47, time = 18.01s
# [BernoulliRBM] Iteration 68, pseudo-likelihood = -2.46, time = 18.19s
# [BernoulliRBM] Iteration 69, pseudo-likelihood = -2.50, time = 18.21s
# [BernoulliRBM] Iteration 70, pseudo-likelihood = -2.52, time = 18.14s
# [BernoulliRBM] Iteration 71, pseudo-likelihood = -2.50, time = 18.30s
# [BernoulliRBM] Iteration 72, pseudo-likelihood = -2.45, time = 18.15s
# [BernoulliRBM] Iteration 73, pseudo-likelihood = -2.51, time = 18.43s
# [BernoulliRBM] Iteration 74, pseudo-likelihood = -2.43, time = 18.11s
# [BernoulliRBM] Iteration 75, pseudo-likelihood = -2.45, time = 18.14s
# [BernoulliRBM] Iteration 76, pseudo-likelihood = -2.41, time = 18.26s
# [BernoulliRBM] Iteration 77, pseudo-likelihood = -2.48, time = 18.13s
# [BernoulliRBM] Iteration 78, pseudo-likelihood = -2.49, time = 18.12s
# [BernoulliRBM] Iteration 79, pseudo-likelihood = -2.51, time = 18.02s
# [BernoulliRBM] Iteration 80, pseudo-likelihood = -2.48, time = 18.04s
# [BernoulliRBM] Iteration 81, pseudo-likelihood = -2.48, time = 18.26s
# [BernoulliRBM] Iteration 82, pseudo-likelihood = -2.45, time = 18.13s
# [BernoulliRBM] Iteration 83, pseudo-likelihood = -2.46, time = 18.12s
# [BernoulliRBM] Iteration 84, pseudo-likelihood = -2.49, time = 18.10s
# [BernoulliRBM] Iteration 85, pseudo-likelihood = -2.46, time = 18.06s
# [BernoulliRBM] Iteration 86, pseudo-likelihood = -2.43, time = 18.05s
# [BernoulliRBM] Iteration 87, pseudo-likelihood = -2.46, time = 17.96s
# [BernoulliRBM] Iteration 88, pseudo-likelihood = -2.45, time = 18.05s
# [BernoulliRBM] Iteration 89, pseudo-likelihood = -2.47, time = 18.16s
# [BernoulliRBM] Iteration 90, pseudo-likelihood = -2.45, time = 18.17s
# [BernoulliRBM] Iteration 91, pseudo-likelihood = -2.49, time = 18.13s
# [BernoulliRBM] Iteration 92, pseudo-likelihood = -2.45, time = 19.05s
# [BernoulliRBM] Iteration 93, pseudo-likelihood = -2.40, time = 17.99s
# [BernoulliRBM] Iteration 94, pseudo-likelihood = -2.50, time = 18.01s
# [BernoulliRBM] Iteration 95, pseudo-likelihood = -2.47, time = 17.95s
# [BernoulliRBM] Iteration 96, pseudo-likelihood = -2.43, time = 18.01s
# [BernoulliRBM] Iteration 97, pseudo-likelihood = -2.43, time = 18.13s
# [BernoulliRBM] Iteration 98, pseudo-likelihood = -2.51, time = 18.15s
# [BernoulliRBM] Iteration 99, pseudo-likelihood = -2.51, time = 18.10s
# [BernoulliRBM] Iteration 100, pseudo-likelihood = -2.42, time = 18.25s
# Pipeline(steps=[('rbm',
#                  BernoulliRBM(learning_rate=0.05, n_components=1024, n_iter=100,
#                               random_state=0, verbose=True)),
#                 ('logistic',
#                  LogisticRegression(C=16000000, solver='newton-cg', tol=1))])

# %%
# Evaluation
print("Starting prediction 1")
Y_pred2 = rbm_features_classifier.predict(X_test)
print("Finished prediction 1")
# Out:
# Starting prediction 1
# Finished prediction 1

# %%
# Avoids long repetitions
output = Y_pred2[0:5]
for i in Y_pred2:
    if i == output[len(output) - 4] and i == output[len(output) - 3] and i == output[len(output) - 2] and i == output[len(output) - 1] and i == output[len(output) - 5]:
        continue
    output = np.append(output,i)

# %%
for  i in range(0,len(output)-500,500):
    output_notes = []
    offset = 0
    # create note and chord objects based on the values generated by the model
    for pattern in output[i:i+500]:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)
        # increase offset each iteration so that notes do not stack
        offset += 0.5
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='RBM_Sklearn_'+ str(int(i/500)) + '.mid')
